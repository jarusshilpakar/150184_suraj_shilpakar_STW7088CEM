# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import LSTM

# %%
df = pd.read_csv('/Gold Price (2013-2023).csv')

# %%
df
# Out:
#             Date     Price      Open      High       Low     Vol. Change %
# 0     12/30/2022  1,826.20  1,821.80  1,832.40  1,819.80  107.50K    0.01%
# 1     12/29/2022  1,826.00  1,812.30  1,827.30  1,811.20  105.99K    0.56%
# 2     12/28/2022  1,815.80  1,822.40  1,822.80  1,804.20  118.08K   -0.40%
# 3     12/27/2022  1,823.10  1,808.20  1,841.90  1,808.00  159.62K    0.74%
# 4     12/26/2022  1,809.70  1,805.80  1,811.95  1,805.55      NaN    0.30%
# ...          ...       ...       ...       ...       ...      ...      ...
# 2578  01/08/2013  1,663.20  1,651.50  1,662.60  1,648.80    0.13K    0.97%
# 2579  01/07/2013  1,647.20  1,657.30  1,663.80  1,645.30    0.09K   -0.16%
# 2580  01/04/2013  1,649.90  1,664.40  1,664.40  1,630.00    0.31K   -1.53%
# 2581  01/03/2013  1,675.60  1,688.00  1,689.30  1,664.30    0.19K   -0.85%
# 2582  01/02/2013  1,689.90  1,675.80  1,695.00  1,672.10    0.06K    0.78%
#
# [2583 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2583 entries, 0 to 2582
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2583 non-null   object
#  1   Price     2583 non-null   object
#  2   Open      2583 non-null   object
#  3   High      2583 non-null   object
#  4   Low       2583 non-null   object
#  5   Vol.      2578 non-null   object
#  6   Change %  2583 non-null   object
# dtypes: object(7)
# memory usage: 141.4+ KB

# %%
df.drop(['Vol.', 'Change %'], axis=1, inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
NumCols = df.columns.drop(['Date'])
df[NumCols] = df[NumCols].replace({',': ''}, regex=True)
df[NumCols] = df[NumCols].astype('float64')

# %%
df.head()
# Out:
#         Date   Price    Open    High     Low
# 0 2013-01-02  1689.9  1675.8  1695.0  1672.1
# 1 2013-01-03  1675.6  1688.0  1689.3  1664.3
# 2 2013-01-04  1649.9  1664.4  1664.4  1630.0
# 3 2013-01-07  1647.2  1657.3  1663.8  1645.3
# 4 2013-01-08  1663.2  1651.5  1662.6  1648.8

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
fig = px.line(y=df.Price, x=df.Date)
fig.update_traces(line_color='black')
fig.update_layout(xaxis_title="Date",
                  yaxis_title="Scaled Price",
                  title={'text': "Gold Price History Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
                  plot_bgcolor='rgba(255,223,0,0.8)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bae8f567-327a-4c99-bca5-7a1db452d0b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bae8f567-327a-4c99-bca5-7a1db452d0b9")) {                    Plotly.newPlot(                        "bae8f567-327a-4c99-bca5-7a1db452d0b9",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"black","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-03T00:00:00","2013-06-04T00:00:00","2013-06-05T00:00:00","2013-06-06T00:00:00","2013-06-07T00:00:00","2013-06-10T00:00:00","2013-06-11T00:00:00","2013-06-12T00:00:00","2013-06-13T00:00:00","2013-06-14T00:00:00","2013-06-17T00:00:00","2013-06-18T00:00:00","2013-06-19T00:00:00","2013-06-20T00:00:00","2013-06-21T00:00:00","2013-06-24T00:00:00","2013-06-25T00:00:00","2013-06-26T00:00:00","2013-06-27T00:00:00","2013-06-28T00:00:00","2013-07-01T00:00:00","2013-07-02T00:00:00","2013-07-03T00:00:00","2013-07-04T00:00:00","2013-07-05T00:00:00","2013-07-08T00:00:00","2013-07-09T00:00:00","2013-07-10T00:00:00","2013-07-11T00:00:00","2013-07-12T00:00:00","2013-07-15T00:00:00","2013-07-16T00:00:00","2013-07-17T00:00:00","2013-07-18T00:00:00","2013-07-19T00:00:00","2013-07-22T00:00:00","2013-07-23T00:00:00","2013-07-24T00:00:00","2013-07-25T00:00:00","20 ...

# %%
test_size = df[df.Date.dt.year==2022].shape[0]
test_size
# Out:
# 260

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df.Date[:-test_size], df.Price[:-test_size], color='black', lw=2)
plt.plot(df.Date[-test_size:], df.Price[-test_size:], color='blue', lw=2)
plt.title('Gold Price Training and Test Sets', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %%
scaler = MinMaxScaler()
scaler.fit(df.Price.values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
window_size = 60

# %%
train_data = df.Price[:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

# %%
X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
test_data = df.Price[-test_size-60:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])

# %%
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)
print('X_test Shape:  ', X_test.shape)
print('y_test Shape:  ', y_test.shape)
# Out:
# X_train Shape:  (2263, 60, 1)
# y_train Shape:  (2263, 1)
# X_test Shape:   (260, 60, 1)
# y_test Shape:   (260, 1)

# %%
def define_model():
    input1 = Input(shape=(window_size,1))
    x = LSTM(units = 64, return_sequences=True)(input1)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64, return_sequences=True)(x)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64)(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation='softmax')(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='Nadam')
    model.summary()

    return model

# %%
model = define_model()
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 60, 1)]           0
#
#  lstm_6 (LSTM)               (None, 60, 64)            16896
#
#  dropout_6 (Dropout)         (None, 60, 64)            0
#
#  lstm_7 (LSTM)               (None, 60, 64)            33024
#
#  dropout_7 (Dropout)         (None, 60, 64)            0
#
#  lstm_8 (LSTM)               (None, 64)                33024
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 85057 (332.25 KB)
# Trainable params: 85057 (332.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/150
# 64/64 [==============================] - 29s 274ms/step - loss: 0.0395 - val_loss: 0.0845
# Epoch 2/150
# 64/64 [==============================] - 9s 133ms/step - loss: 0.0115 - val_loss: 0.0360
# Epoch 3/150
# 64/64 [==============================] - 9s 146ms/step - loss: 0.0068 - val_loss: 0.0150
# Epoch 4/150
# 64/64 [==============================] - 7s 102ms/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 5/150
# 64/64 [==============================] - 8s 121ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 6/150
# 64/64 [==============================] - 7s 102ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 7/150
# 64/64 [==============================] - 8s 121ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 8/150
# 64/64 [==============================] - 7s 112ms/step - loss: 0.0015 - val_loss: 0.0054
# Epoch 9/150
# 64/64 [==============================] - 7s 110ms/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 10/150
# 64/64 [==============================] - 8s 122ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 11/150
# 64/64 [==============================] - 7s 102ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 12/150
# 64/64 [==============================] - 8s 131ms/step - loss: 0.0011 - val_loss: 0.0060
# Epoch 13/150
# 64/64 [==============================] - 7s 111ms/step - loss: 0.0010 - val_loss: 0.0061
# Epoch 14/150
# 64/64 [==============================] - 8s 122ms/step - loss: 9.8922e-04 - val_loss: 0.0028
# Epoch 15/150
# 64/64 [==============================] - 7s 110ms/step - loss: 9.3580e-04 - val_loss: 0.0022
# Epoch 16/150
# 64/64 [==============================] - 7s 111ms/step - loss: 9.3332e-04 - val_loss: 0.0030
# Epoch 17/150
# 64/64 [==============================] - 8s 123ms/step - loss: 8.8274e-04 - val_loss: 0.0036
# Epoch 18/150
# 64/64 [==============================] - 7s 104ms/step - loss: 9.4915e-04 - val_loss: 0.0013
# Epoch 19/150
# 64/64 [==============================] - 8s 121ms/step - loss: 8.9143e-04 - val_loss: 0.0015
# Epoch 20/150
# 64/64 [==============================] - 6s 101ms/step - loss: 7.9559e-04 - val_loss: 0.0068
# Epoch 21/150
# 64/64 [==============================] - 8s 120ms/step - loss: 7.7482e-04 - val_loss: 0.0059
# Epoch 22/150
# 64/64 [==============================] - 7s 102ms/step - loss: 8.0316e-04 - val_loss: 0.0012
# Epoch 23/150
# 64/64 [==============================] - 8s 121ms/step - loss: 7.1877e-04 - val_loss: 0.0063
# Epoch 24/150
# 64/64 [==============================] - 8s 128ms/step - loss: 7.4326e-04 - val_loss: 0.0011
# Epoch 25/150
# 64/64 [==============================] - 7s 107ms/step - loss: 6.7425e-04 - val_loss: 0.0044
# Epoch 26/150
# 64/64 [==============================] - 8s 131ms/step - loss: 6.7952e-04 - val_loss: 9.4827e-04
# Epoch 27/150
# 64/64 [==============================] - 7s 102ms/step - loss: 6.3406e-04 - val_loss: 9.4083e-04
# Epoch 28/150
# 64/64 [==============================] - 8s 121ms/step - loss: 6.2843e-04 - val_loss: 8.0083e-04
# Epoch 29/150
# 64/64 [==============================] - 6s 101ms/step - loss: 6.2452e-04 - val_loss: 0.0013
# Epoch 30/150
# 64/64 [==============================] - 8s 121ms/step - loss: 6.6342e-04 - val_loss: 0.0010
# Epoch 31/150
# 64/64 [==============================] - 7s 111ms/step - loss: 6.0337e-04 - val_loss: 0.0010
# Epoch 32/150
# 64/64 [==============================] - 7s 110ms/step - loss: 5.8145e-04 - val_loss: 9.6069e-04
# Epoch 33/150
# 64/64 [==============================] - 8s 122ms/step - loss: 5.7616e-04 - val_loss: 6.9426e-04
# Epoch 34/150
# 64/64 [==============================] - 7s 104ms/step - loss: 5.8346e-04 - val_loss: 6.1035e-04
# Epoch 35/150
# 64/64 [==============================] - 8s 122ms/step - loss: 6.2161e-04 - val_loss: 0.0011
# Epoch 36/150
# 64/64 [==============================] - 6s 101ms/step - loss: 5.8824e-04 - val_loss: 0.0025
# Epoch 37/150
# 64/64 [==============================] - 8s 128ms/step - loss: 5.5111e-04 - val_loss: 5.6271e-04
# Epoch 38/150
# 64/64 [==============================] - 7s 103ms/step - loss: 5.4297e-04 - val_loss: 0.0011
# Epoch 39/150
# 64/64 [==============================] - 8s 118ms/step - loss: 5.2868e-04 - val_loss: 9.2635e-04
# Epoch 40/150
# 64/64 [==============================] - 8s 118ms/step - loss: 5.2544e-04 - val_loss: 0.0014
# Epoch 41/150
# 64/64 [==============================] - 7s 105ms/step - loss: 4.7140e-04 - val_loss: 5.9152e-04
# Epoch 42/150
# 64/64 [==============================] - 8s 121ms/step - loss: 5.4316e-04 - val_loss: 7.6729e-04
# Epoch 43/150
# 64/64 [==============================] - 7s 102ms/step - loss: 4.9367e-04 - val_loss: 0.0022
# Epoch 44/150
# 64/64 [==============================] - 8s 121ms/step - loss: 5.3521e-04 - val_loss: 5.8889e-04
# Epoch 45/150
# 64/64 [==============================] - 6s 101ms/step - loss: 5.0822e-04 - val_loss: 5.3584e-04
# Epoch 46/150
# 64/64 [==============================] - 8s 121ms/step - loss: 4.5737e-04 - val_loss: 9.6762e-04
# Epoch 47/150
# 64/64 [==============================] - 7s 102ms/step - loss: 4.6216e-04 - val_loss: 4.7765e-04
# Epoch 48/150
# 64/64 [==============================] - 8s 121ms/step - loss: 4.6711e-04 - val_loss: 6.0662e-04
# Epoch 49/150
# 64/64 [==============================] - 8s 120ms/step - loss: 4.6575e-04 - val_loss: 0.0036
# Epoch 50/150
# 64/64 [==============================] - 7s 105ms/step - loss: 4.7639e-04 - val_loss: 0.0011
# Epoch 51/150
# 64/64 [==============================] - 8s 122ms/step - loss: 4.5683e-04 - val_loss: 0.0013
# Epoch 52/150
# 64/64 [==============================] - 7s 102ms/step - loss: 4.9975e-04 - val_loss: 6.5179e-04
# Epoch 53/150
# 64/64 [==============================] - 8s 121ms/step - loss: 4.4436e-04 - val_loss: 0.0022
# Epoch 54/150
# 64/64 [==============================] - 7s 102ms/step - loss: 4.4696e-04 - val_loss: 0.0013
# Epoch 55/150
# 64/64 [==============================] - 8s 121ms/step - loss: 4.4367e-04 - val_loss: 0.0018
# Epoch 56/150
# 64/64 [==============================] - 7s 106ms/step - loss: 4.4397e-04 - val_loss: 4.7605e-04
# Epoch 57/150
# 64/64 [==============================] - 8s 118ms/step - loss: 4.1530e-04 - val_loss: 4.6037e-04
# Epoch 58/150
# 64/64 [==============================] - 8s 118ms/step - loss: 4.1892e-04 - val_loss: 0.0025
# Epoch 59/150
# 64/64 [==============================] - 7s 105ms/step - loss: 4.0815e-04 - val_loss: 7.3351e-04
# Epoch 60/150
# 64/64 [==============================] - 8s 124ms/step - loss: 4.3914e-04 - val_loss: 7.7893e-04
# Epoch 61/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.8645e-04 - val_loss: 0.0011
# Epoch 62/150
# 64/64 [==============================] - 8s 121ms/step - loss: 4.2836e-04 - val_loss: 4.1498e-04
# Epoch 63/150
# 64/64 [==============================] - 7s 102ms/step - loss: 3.8999e-04 - val_loss: 0.0019
# Epoch 64/150
# 64/64 [==============================] - 8s 121ms/step - loss: 4.1977e-04 - val_loss: 5.9634e-04
# Epoch 65/150
# 64/64 [==============================] - 7s 108ms/step - loss: 4.0466e-04 - val_loss: 5.9760e-04
# Epoch 66/150
# 64/64 [==============================] - 8s 117ms/step - loss: 4.0374e-04 - val_loss: 4.9177e-04
# Epoch 67/150
# 64/64 [==============================] - 8s 119ms/step - loss: 3.7921e-04 - val_loss: 7.1871e-04
# Epoch 68/150
# 64/64 [==============================] - 7s 104ms/step - loss: 4.1567e-04 - val_loss: 7.7009e-04
# Epoch 69/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.7848e-04 - val_loss: 8.9719e-04
# Epoch 70/150
# 64/64 [==============================] - 7s 102ms/step - loss: 3.7640e-04 - val_loss: 0.0012
# Epoch 71/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.8684e-04 - val_loss: 5.9535e-04
# Epoch 72/150
# 64/64 [==============================] - 7s 102ms/step - loss: 3.7584e-04 - val_loss: 7.0254e-04
# Epoch 73/150
# 64/64 [==============================] - 8s 121ms/step - loss: 4.0129e-04 - val_loss: 7.1361e-04
# Epoch 74/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.7484e-04 - val_loss: 4.9902e-04
# Epoch 75/150
# 64/64 [==============================] - 8s 119ms/step - loss: 3.7465e-04 - val_loss: 8.2350e-04
# Epoch 76/150
# 64/64 [==============================] - 8s 119ms/step - loss: 3.6417e-04 - val_loss: 7.2379e-04
# Epoch 77/150
# 64/64 [==============================] - 7s 105ms/step - loss: 3.5092e-04 - val_loss: 7.9564e-04
# Epoch 78/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.9093e-04 - val_loss: 8.4874e-04
# Epoch 79/150
# 64/64 [==============================] - 7s 102ms/step - loss: 3.6472e-04 - val_loss: 9.2606e-04
# Epoch 80/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.8600e-04 - val_loss: 7.7949e-04
# Epoch 81/150
# 64/64 [==============================] - 7s 104ms/step - loss: 3.6624e-04 - val_loss: 5.8806e-04
# Epoch 82/150
# 64/64 [==============================] - 8s 121ms/step - loss: 4.0636e-04 - val_loss: 5.2964e-04
# Epoch 83/150
# 64/64 [==============================] - 7s 105ms/step - loss: 3.4202e-04 - val_loss: 8.4943e-04
# Epoch 84/150
# 64/64 [==============================] - 8s 119ms/step - loss: 3.5974e-04 - val_loss: 0.0010
# Epoch 85/150
# 64/64 [==============================] - 8s 118ms/step - loss: 3.6722e-04 - val_loss: 6.3686e-04
# Epoch 86/150
# 64/64 [==============================] - 7s 104ms/step - loss: 3.4768e-04 - val_loss: 5.2802e-04
# Epoch 87/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.4174e-04 - val_loss: 7.8423e-04
# Epoch 88/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.4675e-04 - val_loss: 0.0014
# Epoch 89/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.7340e-04 - val_loss: 7.6673e-04
# Epoch 90/150
# 64/64 [==============================] - 7s 104ms/step - loss: 3.3504e-04 - val_loss: 8.6753e-04
# Epoch 91/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.5428e-04 - val_loss: 0.0017
# Epoch 92/150
# 64/64 [==============================] - 7s 111ms/step - loss: 3.6411e-04 - val_loss: 0.0013
# Epoch 93/150
# 64/64 [==============================] - 7s 112ms/step - loss: 3.5281e-04 - val_loss: 7.7116e-04
# Epoch 94/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.5280e-04 - val_loss: 0.0011
# Epoch 95/150
# 64/64 [==============================] - 7s 102ms/step - loss: 3.3114e-04 - val_loss: 8.6979e-04
# Epoch 96/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.4436e-04 - val_loss: 9.1936e-04
# Epoch 97/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.4889e-04 - val_loss: 6.3157e-04
# Epoch 98/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.6691e-04 - val_loss: 9.8457e-04
# Epoch 99/150
# 64/64 [==============================] - 7s 102ms/step - loss: 3.3702e-04 - val_loss: 0.0015
# Epoch 100/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.4143e-04 - val_loss: 0.0010
# Epoch 101/150
# 64/64 [==============================] - 7s 108ms/step - loss: 3.4669e-04 - val_loss: 6.7054e-04
# Epoch 102/150
# 64/64 [==============================] - 7s 115ms/step - loss: 3.3262e-04 - val_loss: 0.0015
# Epoch 103/150
# 64/64 [==============================] - 8s 120ms/step - loss: 3.6671e-04 - val_loss: 0.0010
# Epoch 104/150
# 64/64 [==============================] - 6s 101ms/step - loss: 3.2892e-04 - val_loss: 0.0010
# Epoch 105/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.3328e-04 - val_loss: 6.8522e-04
# Epoch 106/150
# 64/64 [==============================] - 7s 102ms/step - loss: 3.4250e-04 - val_loss: 5.5350e-04
# Epoch 107/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.5537e-04 - val_loss: 0.0012
# Epoch 108/150
# 64/64 [==============================] - 6s 101ms/step - loss: 3.2302e-04 - val_loss: 0.0013
# Epoch 109/150
# 64/64 [==============================] - 8s 124ms/step - loss: 2.9906e-04 - val_loss: 7.2943e-04
# Epoch 110/150
# 64/64 [==============================] - 7s 104ms/step - loss: 3.5001e-04 - val_loss: 0.0010
# Epoch 111/150
# 64/64 [==============================] - 8s 118ms/step - loss: 3.3988e-04 - val_loss: 0.0012
# Epoch 112/150
# 64/64 [==============================] - 8s 119ms/step - loss: 3.0890e-04 - val_loss: 0.0013
# Epoch 113/150
# 64/64 [==============================] - 7s 105ms/step - loss: 3.0509e-04 - val_loss: 0.0013
# Epoch 114/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.2919e-04 - val_loss: 6.9504e-04
# Epoch 115/150
# 64/64 [==============================] - 6s 102ms/step - loss: 3.2952e-04 - val_loss: 7.3319e-04
# Epoch 116/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.1159e-04 - val_loss: 0.0010
# Epoch 117/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.0932e-04 - val_loss: 0.0023
# Epoch 118/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.2778e-04 - val_loss: 0.0017
# Epoch 119/150
# 64/64 [==============================] - 7s 111ms/step - loss: 3.1228e-04 - val_loss: 0.0013
# Epoch 120/150
# 64/64 [==============================] - 7s 113ms/step - loss: 3.1034e-04 - val_loss: 0.0013
# Epoch 121/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.2988e-04 - val_loss: 6.1050e-04
# Epoch 122/150
# 64/64 [==============================] - 7s 102ms/step - loss: 3.0195e-04 - val_loss: 8.2924e-04
# Epoch 123/150
# 64/64 [==============================] - 8s 123ms/step - loss: 2.9407e-04 - val_loss: 0.0023
# Epoch 124/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.1740e-04 - val_loss: 7.2001e-04
# Epoch 125/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.1212e-04 - val_loss: 8.4986e-04
# Epoch 126/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.2138e-04 - val_loss: 8.6891e-04
# Epoch 127/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.1033e-04 - val_loss: 5.9269e-04
# Epoch 128/150
# 64/64 [==============================] - 7s 109ms/step - loss: 3.2852e-04 - val_loss: 9.0928e-04
# Epoch 129/150
# 64/64 [==============================] - 7s 114ms/step - loss: 3.2844e-04 - val_loss: 0.0013
# Epoch 130/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.1065e-04 - val_loss: 7.4462e-04
# Epoch 131/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.0590e-04 - val_loss: 9.8837e-04
# Epoch 132/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.0966e-04 - val_loss: 8.7774e-04
# Epoch 133/150
# 64/64 [==============================] - 7s 102ms/step - loss: 3.0188e-04 - val_loss: 6.8229e-04
# Epoch 134/150
# 64/64 [==============================] - 8s 123ms/step - loss: 3.0842e-04 - val_loss: 9.9746e-04
# Epoch 135/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.2475e-04 - val_loss: 0.0016
# Epoch 136/150
# 64/64 [==============================] - 8s 122ms/step - loss: 2.9314e-04 - val_loss: 6.9862e-04
# Epoch 137/150
# 64/64 [==============================] - 7s 112ms/step - loss: 3.0211e-04 - val_loss: 0.0015
# Epoch 138/150
# 64/64 [==============================] - 7s 112ms/step - loss: 3.2080e-04 - val_loss: 0.0012
# Epoch 139/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.1692e-04 - val_loss: 8.4409e-04
# Epoch 140/150
# 64/64 [==============================] - 7s 102ms/step - loss: 2.8872e-04 - val_loss: 0.0012
# Epoch 141/150
# 64/64 [==============================] - 8s 122ms/step - loss: 2.8842e-04 - val_loss: 9.1857e-04
# Epoch 142/150
# 64/64 [==============================] - 7s 104ms/step - loss: 3.0855e-04 - val_loss: 0.0013
# Epoch 143/150
# 64/64 [==============================] - 8s 122ms/step - loss: 2.9226e-04 - val_loss: 0.0010
# Epoch 144/150
# 64/64 [==============================] - 7s 103ms/step - loss: 2.9007e-04 - val_loss: 0.0016
# Epoch 145/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.0970e-04 - val_loss: 6.9345e-04
# Epoch 146/150
# 64/64 [==============================] - 7s 112ms/step - loss: 3.1166e-04 - val_loss: 0.0020
# Epoch 147/150
# 64/64 [==============================] - 7s 110ms/step - loss: 3.0710e-04 - val_loss: 9.0818e-04
# Epoch 148/150
# 64/64 [==============================] - 8s 121ms/step - loss: 2.9481e-04 - val_loss: 9.0980e-04
# Epoch 149/150
# 64/64 [==============================] - 7s 103ms/step - loss: 2.9385e-04 - val_loss: 0.0015
# Epoch 150/150
# 64/64 [==============================] - 8s 123ms/step - loss: 2.9969e-04 - val_loss: 0.0012

# %%
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 9/9 [==============================] - 1s 78ms/step - loss: 9.4701e-04
# 9/9 [==============================] - 2s 26ms/step

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
Accuracy = 1 - MAPE

# %%
print("Test Loss:", result)
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.0009470069198869169
# Test MAPE: 0.03434262725942311
# Test Accuracy: 0.9656573727405768

# %%
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df['Date'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Model Performance on Gold Price Prediction', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()
